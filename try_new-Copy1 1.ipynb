# %%
# HSV conversion of images
import cv2 
import os 
import glob 
import matplotlib.pyplot as plt
img_dir = "D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_train\\Live\\Indoor" # Enter Directory of all images  
data_path = os.path.join(img_dir,'*g') 
files = glob.glob(data_path) 
directory = r'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_HSV_train\\Live\\Indoor'
#print(files)
data = [] 
path=''
#file_names.append(os.path.basename(file.name))
for f1 in files: 
    print(f1)
    img = cv2.imread(f1) 
    os.chdir(directory) 
    print("Before saving")   
    print(os.listdir(directory)) 
    c = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    cv2.imwrite(os.path.basename(f1), c)
     
    print("After saving")  
    print(os.listdir(directory)) 
    #plt.imshow(img)
    #plt.show()
    #data.append(img)
    
  # D:\Fall 2021\Applied ML - AIT 736\final new\Experiment_1_patch\Train_HSV\Live\Indoor
  # D:\Fall 2021\Applied ML - AIT 736\final new\Experiment_1_patch\Train_HSV\Spoof\Indoor
   # D:\Fall 2021\Applied ML - AIT 736\final new\Experiment_1_patch\Test_HSV\Live\Indoor
# D:\Fall 2021\Applied ML - AIT 736\final new\Experiment_1_patch\Test_HSV\Spoof\Indoor

# %%
# from resnet import *
import torch
import torch
import torch.nn as nn 
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset, DataLoader, random_split, SubsetRandomSampler, WeightedRandomSampler
import torch.nn.functional as F 
from sklearn.model_selection import KFold
import os
import io
import cv2
from PIL import *
import PIL.ImageOps
import requests
from PIL import Image
import numpy as np

#import matplotlib
#matplotlib.use('agg')
#import matplotlib.pyplot as plt
import torch
import torch.nn as nn 
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset, DataLoader, random_split, SubsetRandomSampler, WeightedRandomSampler
import torch.nn.functional as F 
from torch.optim import lr_scheduler
import time
import copy
from sklearn.model_selection import KFold
import os
import io
import cv2
from PIL import *
import PIL.ImageOps
from PIL import Image
from sklearn.metrics import roc_curve, auc
import math

# %%
model = models.resnet18(pretrained=True)
print(model.eval())

# move the input and model to GPU for speed if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )
# device(type='cuda', index=0)

# %% [markdown]
# ## White v/s White Background(Baseline) - RGB Color space

# %%
for i in os.listdir('D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\Train'):
    print(i)
    link_train = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\Train\\'+i+''
    link_test = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\Test\\'+i+''
    model_address = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\model\\{}.pth'.format(i,i)

    transform    = transforms.Compose([
                                        
                                        transforms.Resize((224,224)),
                                        transforms.ToTensor(),
                                        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                    std=[0.229, 0.224, 0.225])
                                ])

    training_dataset = datasets.ImageFolder(link_train ,transform = transform)
    testing_dataset = datasets.ImageFolder(link_test,transform = transform)

    training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=48, shuffle=True)
    # testing data 

    val_dataset, test_dataset = random_split(testing_dataset,[math.floor(len(testing_dataset)*0.6), math.ceil(len(testing_dataset)*0.4)])

    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = 32, shuffle=False)
    testing_loader = torch.utils.data.DataLoader(test_dataset, batch_size = 32, shuffle=False)

    print("Training data set after removing two instances : {}".format(len(training_dataset)))
    print("Complete Val data set : {}".format(len(val_dataset)))
    print("Complete Test data set : {}".format(len(test_dataset)))
    classes = ('Live', 'Spoof')

    for param in model.parameters():
        param.requires_grad = False

    import torch.nn as nn

    n_inputs = model.fc.in_features
    last_layer = nn.Linear(n_inputs, len(classes))
    model.fc=nn.Linear(n_inputs,2)
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)


    splits = KFold(n_splits= 3, shuffle = True, random_state = 42)

    epochs = 1
    running_loss_history = []
    running_corrects_history = []
    val_running_loss_history = []
    val_running_corrects_history = []

    for e in range(epochs):
        running_loss = 0.0
        running_corrects = 0.0
        val_running_loss = 0.0
        val_running_corrects = 0.0
        for inputs, labels in training_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            _, preds = torch.max(outputs, 1)
            running_loss += loss.item()
            running_corrects += torch.sum(preds == labels.data)
        else:
            with torch.no_grad():
                for val_inputs, val_labels in val_loader:
                    val_inputs = val_inputs.to(device)
                    val_labels = val_labels.to(device)
                    val_outputs = model(val_inputs)
                    val_loss = criterion(val_outputs, val_labels)

                    _, val_preds = torch.max(val_outputs, 1)
                    val_running_loss += val_loss.item()
                    val_running_corrects += torch.sum(val_preds == val_labels.data)
        
            epoch_loss = running_loss/len(training_loader.dataset)
            epoch_acc = running_corrects.float()/ len(training_loader.dataset)
            running_loss_history.append(epoch_loss)
            running_corrects_history.append(epoch_acc)

            val_epoch_loss = val_running_loss/len(val_loader.dataset)
            val_epoch_acc = val_running_corrects.float()/ len(val_loader.dataset)
            val_running_loss_history.append(val_epoch_loss)
            val_running_corrects_history.append(val_epoch_acc)
            print('epoch :', (e+1))
            print('training acc {:.4f} '.format(epoch_acc.item()))
            print('validation acc {:.4f} '.format( val_epoch_acc.item()))

    torch.save(model.state_dict(),model_address) 
# #ADD address here with filename
# Out:
# Live
# Training data set after removing two instances : 768
# Complete Val data set : 614
# Complete Test data set : 410
# epoch : 1
# training acc 0.7617
# validation acc 0.8599
# Spoof
# Training data set after removing two instances : 2048
# Complete Val data set : 1228
# Complete Test data set : 820
# epoch : 1
# training acc 0.7646
# validation acc 0.8746

# %%
plt.plot(running_loss_history, label='training loss')
plt.plot(val_running_loss_history, label='validation loss')
plt.legend()

# %%
plt.plot(running_corrects_history, label='training accuracy')
plt.plot(val_running_corrects_history, label='validation accuracy')
plt.legend()

# %%
# from resnet import *
import matplotlib.pyplot as plt
import torch.nn as nn 
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset, DataLoader, random_split, SubsetRandomSampler, WeightedRandomSampler
import torch.nn.functional as F 
from sklearn.model_selection import KFold
import os
import io
import cv2
from PIL import *
import PIL.ImageOps
import requests
from PIL import Image
import numpy as np
#import matplotlib
#matplotlib.use('agg')
#import matplotlib.pyplot as plt
import torch
import torch.nn as nn 
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset, DataLoader, random_split, SubsetRandomSampler, WeightedRandomSampler
import torch.nn.functional as F 
from torch.optim import lr_scheduler
import time
import copy
from sklearn.model_selection import KFold
import os
import io
import cv2
from PIL import *
import PIL.ImageOps
from PIL import Image
from sklearn.metrics import roc_curve, auc,roc_auc_score

model = models.resnet18(pretrained=True)
# print(model.eval())

# move the input and model to GPU for speed if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")




import math 


for i in os.listdir('D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\Test'):
    print(i)
    link_train = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\Train\\'+i+''
    link_test = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\Test\\'+i+''
    model_address = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\model\\{}.pth'.format(i,i)
    
    
    text_file = i

    transform    = transforms.Compose([
                                        
                                    transforms.Resize((224,224)),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                    std=[0.229, 0.224, 0.225])
                                ])

    training_dataset = datasets.ImageFolder(link_train ,transform = transform)
    testing_dataset = datasets.ImageFolder(link_test,transform = transform)

    training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=48, shuffle=True)
    # testing data 

    val_dataset, test_dataset = random_split(testing_dataset,[math.floor(len(testing_dataset)*0.6), math.ceil(len(testing_dataset)*0.4)])

    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = 32, shuffle=False)
    testing_loader = torch.utils.data.DataLoader(test_dataset, batch_size = 32, shuffle=False)


    print("Training data set after removing two instances : {}".format(len(training_dataset)))
    print("Complete Val data set : {}".format(len(val_dataset)))
    print("Complete Test data set : {}".format(len(test_dataset)))
    classes = ('Live', 'Spoof')

    for param in model.parameters():
        param.requires_grad = False

    import torch.nn as nn

    n_inputs = model.fc.in_features
    last_layer = nn.Linear(n_inputs, len(classes))
    model.fc=nn.Linear(n_inputs,2)
    # model.to(device)
   # print(model.eval())
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)


    model.load_state_dict(torch.load(model_address))

    def get_all_preds(model,loader):
        all_preds = torch.tensor([])
        #   all_preds.to(device)
        for batch in loader:
            images,labels = batch
            #   images = images.to(device)
            #   labels = labels.to(device)
        

            preds = model(images)
            all_preds = torch.cat((all_preds , preds),dim=0)
        return all_preds


    with torch.no_grad():
        prediction_loader = torch.utils.data.DataLoader(test_dataset,batch_size = 32)
        test_pred = get_all_preds(model,prediction_loader)
        
    print(test_pred.shape)
    test_labels = [label for _, label in test_dataset]
    # print(test_labels)

    test_set = torch.FloatTensor(test_labels)


    def get_num_correct(preds,labels):
        return preds.argmax(dim=1).eq(labels).sum().item()

    pred_correct = get_num_correct(test_pred,test_set)
    # print('total correct:',pred_correct)
    # test accuracy


    stacked = torch.stack((test_set,test_pred.argmax(dim=1)),dim=1)



    t11=[]
    p11=[]
    for p in stacked:
        t1,p1=p.tolist()
        t11.append(t1)
        p11.append(p1)
        
        

    from sklearn.metrics import confusion_matrix
    # print('Confusion Matrix',confusion_matrix(t11,p11))


    m = nn.Softmax(dim=1)
    # input = torch.randn(2, 3)
    # output = m(input)
    test_prediction = m(test_pred)
    
    

    far, tpr, threshold = roc_curve(test_set ,
                                        test_prediction [:,1],
                                        drop_intermediate = True )
    
     #calculate AUC of model
    auc = roc_auc_score(test_set ,test_prediction [:,1])
    print('area under curce:',auc)
 
    #print(far, tpr,threshold)
    plt.figure(figsize=(6,4))
   
    plt.plot(far, tpr, linewidth=2)

    plt.plot([0,1], [0,1], 'k--' )

    plt.rcParams['font.size'] = 12
    plt.fill_between(far, tpr, facecolor='lightgreen', alpha=0.7)
    plt.text(0.95, 0.05, 'AUC = %0.4f' % auc, ha='right', fontsize=12, weight='bold', color='blue')
    plt.title(' ROC curve - Baseline (White v/s White Background)')

    plt.xlabel('False Positive Rate (1 - Specificity)')

    plt.ylabel('True Positive Rate (Sensitivity)')

    plt.show()
   

    def compute_eer(fpr,tpr,threshold):
        """ Returns equal error rate (EER) and the corresponding threshold. """
        fnr = 1-tpr
        abs_diffs = np.abs(fpr - fnr)
        min_index = np.argmin(abs_diffs)
        eer = np.mean((fpr[min_index], fnr[min_index]))
        return eer*100

    print('compute_eer',compute_eer(far,tpr,threshold))
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import precision_score
    from sklearn.metrics import recall_score
    from sklearn.metrics import f1_score
    Accuracies = accuracy_score(t11,p11)
    Precision = precision_score(t11,p11)
    Recall = recall_score(t11,p11)
    F1Score = f1_score(t11,p11)

    with open("D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\"+text_file+".txt", "a") as f:
        print('accuracy:',pred_correct/len(test_dataset),file=f)
        print('Accuracy:',Accuracies,file=f)
        print('Precision',Precision,file=f)
        print('Recall',Recall,file=f)
        print('F1Score',F1Score,file=f)
        print('Confusion Matrix',confusion_matrix(t11,p11),file=f)
        print('compute_eer',compute_eer(far,tpr,threshold),file=f)
        print('area under the curve',auc,file=f)
# Out:
# Live
# Training data set after removing two instances : 768
# Complete Val data set : 614
# Complete Test data set : 410
# torch.Size([410, 2])
# area under curce: 0.713421658986175
# compute_eer 35.37586405529954
# Spoof
# Training data set after removing two instances : 2048
# Complete Val data set : 1228
# Complete Test data set : 820
# torch.Size([820, 2])
# area under curce: 0.7517969345011425
# compute_eer 30.975104722010666

# %% [markdown]
# ## Natural v/s Natural Background(Baseline) - RGB Color space

# %%
for i in os.listdir('D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_train'):
    print(i)
    link_train = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_train\\'+i+''
    link_test = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_test\\'+i+''
    model_address = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\model_baseline\\{}.pth'.format(i,i)

    transform    = transforms.Compose([
                                        
                                        transforms.Resize((224,224)),
                                        transforms.ToTensor(),
                                        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                    std=[0.229, 0.224, 0.225])
                                ])

    training_dataset = datasets.ImageFolder(link_train ,transform = transform)
    testing_dataset = datasets.ImageFolder(link_test,transform = transform)

    training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=48, shuffle=True)
    # testing data 

    val_dataset, test_dataset = random_split(testing_dataset,[math.floor(len(testing_dataset)*0.6), math.ceil(len(testing_dataset)*0.4)])

    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = 32, shuffle=False)
    testing_loader = torch.utils.data.DataLoader(test_dataset, batch_size = 32, shuffle=False)

    print("Training data set after removing two instances : {}".format(len(training_dataset)))
    print("Complete Val data set : {}".format(len(val_dataset)))
    print("Complete Test data set : {}".format(len(test_dataset)))
    classes = ('Live', 'Spoof')

    for param in model.parameters():
        param.requires_grad = False

    import torch.nn as nn

    n_inputs = model.fc.in_features
    last_layer = nn.Linear(n_inputs, len(classes))
    model.fc=nn.Linear(n_inputs,2)
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)


    splits = KFold(n_splits= 3, shuffle = True, random_state = 42)

    epochs = 15
    running_loss_history = []
    running_corrects_history = []
    val_running_loss_history = []
    val_running_corrects_history = []

    for e in range(epochs):
        running_loss = 0.0
        running_corrects = 0.0
        val_running_loss = 0.0
        val_running_corrects = 0.0
        for inputs, labels in training_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            _, preds = torch.max(outputs, 1)
            running_loss += loss.item()
            running_corrects += torch.sum(preds == labels.data)
        else:
            with torch.no_grad():
                for val_inputs, val_labels in val_loader:
                    val_inputs = val_inputs.to(device)
                    val_labels = val_labels.to(device)
                    val_outputs = model(val_inputs)
                    val_loss = criterion(val_outputs, val_labels)

                    _, val_preds = torch.max(val_outputs, 1)
                    val_running_loss += val_loss.item()
                    val_running_corrects += torch.sum(val_preds == val_labels.data)
        
            epoch_loss = running_loss/len(training_loader.dataset)
            epoch_acc = running_corrects.float()/ len(training_loader.dataset)
            running_loss_history.append(epoch_loss)
            running_corrects_history.append(epoch_acc)

            val_epoch_loss = val_running_loss/len(val_loader.dataset)
            val_epoch_acc = val_running_corrects.float()/ len(val_loader.dataset)
            val_running_loss_history.append(val_epoch_loss)
            val_running_corrects_history.append(val_epoch_acc)
            print('epoch :', (e+1))
            print('training acc {:.4f} '.format(epoch_acc.item()))
            print('validation acc {:.4f} '.format( val_epoch_acc.item()))

    torch.save(model.state_dict(),model_address) 
# #ADD address here with filename
# Out:
# Live
# Training data set after removing two instances : 768
# Complete Val data set : 614
# Complete Test data set : 410
# epoch : 1
# training acc 0.6823
# validation acc 0.8779
# epoch : 2
# training acc 0.9206
# validation acc 0.9218
# epoch : 3
# training acc 0.9518
# validation acc 0.9316
# epoch : 4
# training acc 0.9596
# validation acc 0.9381
# epoch : 5
# training acc 0.9570
# validation acc 0.9397
# epoch : 6
# training acc 0.9544
# validation acc 0.9414
# epoch : 7
# training acc 0.9596
# validation acc 0.9430
# epoch : 8
# training acc 0.9622
# validation acc 0.9414
# epoch : 9
# training acc 0.9701
# validation acc 0.9414
# epoch : 10
# training acc 0.9727
# validation acc 0.9463
# epoch : 11
# training acc 0.9766
# validation acc 0.9446
# epoch : 12
# training acc 0.9648
# validation acc 0.9430
# epoch : 13
# training acc 0.9661
# validation acc 0.8990
# epoch : 14
# training acc 0.9766
# validation acc 0.9186
# epoch : 15
# training acc 0.9701
# validation acc 0.9365
# Spoof
# Training data set after removing two instances : 2048
# Complete Val data set : 1228
# Complete Test data set : 820
# epoch : 1
# training acc 0.6274
# validation acc 0.7313
# epoch : 2
# training acc 0.7881
# validation acc 0.7752
# epoch : 3
# training acc 0.8188
# validation acc 0.7834
# epoch : 4
# training acc 0.8306
# validation acc 0.8005
# epoch : 5
# training acc 0.8423
# validation acc 0.7980
# epoch : 6
# training acc 0.8472
# validation acc 0.8062
# epoch : 7
# training acc 0.8647
# validation acc 0.8094
# epoch : 8
# training acc 0.8550
# validation acc 0.8086
# epoch : 9
# training acc 0.8672
# validation acc 0.8103
# epoch : 10
# training acc 0.8682
# validation acc 0.8119
# epoch : 11
# training acc 0.8657
# validation acc 0.8094
# epoch : 12
# training acc 0.8628
# validation acc 0.8151
# epoch : 13
# training acc 0.8711
# validation acc 0.8062
# epoch : 14
# training acc 0.8730
# validation acc 0.8021
# epoch : 15
# training acc 0.8809
# validation acc 0.8103

# %%
# from resnet import *
import matplotlib.pyplot as plt
import torch.nn as nn 
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset, DataLoader, random_split, SubsetRandomSampler, WeightedRandomSampler
import torch.nn.functional as F 
from sklearn.model_selection import KFold
import os
import io
import cv2
from PIL import *
import PIL.ImageOps
import requests
from PIL import Image
import numpy as np
#import matplotlib
#matplotlib.use('agg')
#import matplotlib.pyplot as plt
import torch
import torch.nn as nn 
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset, DataLoader, random_split, SubsetRandomSampler, WeightedRandomSampler
import torch.nn.functional as F 
from torch.optim import lr_scheduler
import time
import copy
from sklearn.model_selection import KFold
import os
import io
import cv2
from PIL import *
import PIL.ImageOps
from PIL import Image
from sklearn.metrics import roc_curve, auc,roc_auc_score

model = models.resnet18(pretrained=True)
# print(model.eval())

# move the input and model to GPU for speed if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")




import math 


for i in os.listdir('D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_test'):
    print(i)
    link_train = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_train\\'+i+''
    link_test = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_test\\'+i+''
    model_address = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\model_baseline\\{}.pth'.format(i,i)

    
    text_file = i

    transform    = transforms.Compose([
                                        
                                    transforms.Resize((224,224)),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                    std=[0.229, 0.224, 0.225])
                                ])

    training_dataset = datasets.ImageFolder(link_train ,transform = transform)
    testing_dataset = datasets.ImageFolder(link_test,transform = transform)

    training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=48, shuffle=True)
    # testing data 

    val_dataset, test_dataset = random_split(testing_dataset,[math.floor(len(testing_dataset)*0.6), math.ceil(len(testing_dataset)*0.4)])

    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = 32, shuffle=False)
    testing_loader = torch.utils.data.DataLoader(test_dataset, batch_size = 32, shuffle=False)


    print("Training data set after removing two instances : {}".format(len(training_dataset)))
    print("Complete Val data set : {}".format(len(val_dataset)))
    print("Complete Test data set : {}".format(len(test_dataset)))
    classes = ('Live', 'Spoof')

    for param in model.parameters():
        param.requires_grad = False

    import torch.nn as nn

    n_inputs = model.fc.in_features
    last_layer = nn.Linear(n_inputs, len(classes))
    model.fc=nn.Linear(n_inputs,2)
    # model.to(device)
   # print(model.eval())
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)


    model.load_state_dict(torch.load(model_address))

    def get_all_preds(model,loader):
        all_preds = torch.tensor([])
        #   all_preds.to(device)
        for batch in loader:
            images,labels = batch
            #   images = images.to(device)
            #   labels = labels.to(device)
        

            preds = model(images)
            all_preds = torch.cat((all_preds , preds),dim=0)
        return all_preds


    with torch.no_grad():
        prediction_loader = torch.utils.data.DataLoader(test_dataset,batch_size = 32)
        test_pred = get_all_preds(model,prediction_loader)
        
    print(test_pred.shape)
    test_labels = [label for _, label in test_dataset]
    # print(test_labels)

    test_set = torch.FloatTensor(test_labels)


    def get_num_correct(preds,labels):
        return preds.argmax(dim=1).eq(labels).sum().item()

    pred_correct = get_num_correct(test_pred,test_set)
    # print('total correct:',pred_correct)
    # test accuracy


    stacked = torch.stack((test_set,test_pred.argmax(dim=1)),dim=1)



    t11=[]
    p11=[]
    for p in stacked:
        t1,p1=p.tolist()
        t11.append(t1)
        p11.append(p1)
        
        

    from sklearn.metrics import confusion_matrix
    # print('Confusion Matrix',confusion_matrix(t11,p11))


    m = nn.Softmax(dim=1)
    # input = torch.randn(2, 3)
    # output = m(input)
    test_prediction = m(test_pred)
    
    

    far, tpr, threshold = roc_curve(test_set ,
                                        test_prediction [:,1],
                                        drop_intermediate = True )
    
     #calculate AUC of model
    auc = roc_auc_score(test_set ,test_prediction [:,1])
    print('area under curce:',auc)
 
    #print(far, tpr,threshold)
    plt.figure(figsize=(6,4))
   
    plt.plot(far, tpr, linewidth=2)

    plt.plot([0,1], [0,1], 'k--' )

    plt.rcParams['font.size'] = 12
    plt.fill_between(far, tpr, facecolor='lightgreen', alpha=0.7)
    plt.text(0.95, 0.05, 'AUC = %0.4f' % auc, ha='right', fontsize=12, weight='bold', color='blue')
    plt.title(' ROC curve - Baseline (Natual v/s Natural Background)')

    plt.xlabel('False Positive Rate (1 - Specificity)')

    plt.ylabel('True Positive Rate (Sensitivity)')

    plt.show()
   

    def compute_eer(fpr,tpr,threshold):
        """ Returns equal error rate (EER) and the corresponding threshold. """
        fnr = 1-tpr
        abs_diffs = np.abs(fpr - fnr)
        min_index = np.argmin(abs_diffs)
        eer = np.mean((fpr[min_index], fnr[min_index]))
        return eer*100

    print('compute_eer',compute_eer(far,tpr,threshold))
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import precision_score
    from sklearn.metrics import recall_score
    from sklearn.metrics import f1_score
    Accuracies = accuracy_score(t11,p11)
    Precision = precision_score(t11,p11)
    Recall = recall_score(t11,p11)
    F1Score = f1_score(t11,p11)

    with open("D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\"+text_file+".txt", "a") as f:
        print('accuracy:',pred_correct/len(test_dataset),file=f)
        print('Accuracy:',Accuracies,file=f)
        print('Precision',Precision,file=f)
        print('Recall',Recall,file=f)
        print('F1Score',F1Score,file=f)
        print('Confusion Matrix',confusion_matrix(t11,p11),file=f)
        print('compute_eer',compute_eer(far,tpr,threshold),file=f)
        print('area under the curve',auc,file=f)
# Out:
# Live
# Training data set after removing two instances : 768
# Complete Val data set : 614
# Complete Test data set : 410
# torch.Size([410, 2])
# area under curce: 0.9867734324730106
# compute_eer 4.63168179976645
# Spoof
# Training data set after removing two instances : 2048
# Complete Val data set : 1228
# Complete Test data set : 820
# torch.Size([820, 2])
# area under curce: 0.9028383435163096
# compute_eer 18.902558733067206

# %% [markdown]
# ## White(train) v/s Natural(test) - HSV Color space

# %%
for i in os.listdir('D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\Train_HSV'):
    print(i)
    link_train = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\Train_HSV\\'+i+''
    link_test = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_HSV_test\\'+i+''
    model_address = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\model_whi_vs_nat\\{}.pth'.format(i,i)

    transform    = transforms.Compose([
                                        
                                        transforms.Resize((227,227)),
                                        transforms.ToTensor(),
                                        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                    std=[0.229, 0.224, 0.225])
                                ])

    training_dataset = datasets.ImageFolder(link_train ,transform = transform)
    testing_dataset = datasets.ImageFolder(link_test,transform = transform)

    training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=48, shuffle=True)
    # testing data 

    val_dataset, test_dataset = random_split(testing_dataset,[math.floor(len(testing_dataset)*0.6), math.ceil(len(testing_dataset)*0.4)])

    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = 32, shuffle=False)
    testing_loader = torch.utils.data.DataLoader(test_dataset, batch_size = 32, shuffle=False)

    print("Training data set after removing two instances : {}".format(len(training_dataset)))
    print("Complete Val data set : {}".format(len(val_dataset)))
    print("Complete Test data set : {}".format(len(test_dataset)))
    classes = ('Live', 'Spoof')

    for param in model.parameters():
        param.requires_grad = False

    import torch.nn as nn

    n_inputs = model.fc.in_features
    last_layer = nn.Linear(n_inputs, len(classes))
    model.fc=nn.Linear(n_inputs,2)
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)


    splits = KFold(n_splits= 3, shuffle = True, random_state = 42)

    epochs = 15
    running_loss_history = []
    running_corrects_history = []
    val_running_loss_history = []
    val_running_corrects_history = []

    for e in range(epochs):
        running_loss = 0.0
        running_corrects = 0.0
        val_running_loss = 0.0
        val_running_corrects = 0.0
        for inputs, labels in training_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            _, preds = torch.max(outputs, 1)
            running_loss += loss.item()
            running_corrects += torch.sum(preds == labels.data)
        else:
            with torch.no_grad():
                for val_inputs, val_labels in val_loader:
                    val_inputs = val_inputs.to(device)
                    val_labels = val_labels.to(device)
                    val_outputs = model(val_inputs)
                    val_loss = criterion(val_outputs, val_labels)

                    _, val_preds = torch.max(val_outputs, 1)
                    val_running_loss += val_loss.item()
                    val_running_corrects += torch.sum(val_preds == val_labels.data)
        
            epoch_loss = running_loss/len(training_loader.dataset)
            epoch_acc = running_corrects.float()/ len(training_loader.dataset)
            running_loss_history.append(epoch_loss)
            running_corrects_history.append(epoch_acc)

            val_epoch_loss = val_running_loss/len(val_loader.dataset)
            val_epoch_acc = val_running_corrects.float()/ len(val_loader.dataset)
            val_running_loss_history.append(val_epoch_loss)
            val_running_corrects_history.append(val_epoch_acc)
            print('epoch :', (e+1))
            print('training acc {:.4f} '.format(epoch_acc.item()))
            print('validation acc {:.4f} '.format( val_epoch_acc.item()))

    torch.save(model.state_dict(),model_address)
# Out:
# Live
# Training data set after removing two instances : 768
# Complete Val data set : 614
# Complete Test data set : 410
# epoch : 1
# training acc 0.6120
# validation acc 0.6107
# epoch : 2
# training acc 0.8424
# validation acc 0.5277
# epoch : 3
# training acc 0.8945
# validation acc 0.4837
# epoch : 4
# training acc 0.8958
# validation acc 0.4853
# epoch : 5
# training acc 0.9115
# validation acc 0.4837
# epoch : 6
# training acc 0.9167
# validation acc 0.4788
# epoch : 7
# training acc 0.9141
# validation acc 0.4821
# epoch : 8
# training acc 0.9310
# validation acc 0.4756
# epoch : 9
# training acc 0.9258
# validation acc 0.4756
# epoch : 10
# training acc 0.9310
# validation acc 0.4772
# epoch : 11
# training acc 0.9336
# validation acc 0.4756
# epoch : 12
# training acc 0.9388
# validation acc 0.4756
# epoch : 13
# training acc 0.9414
# validation acc 0.4756
# epoch : 14
# training acc 0.9440
# validation acc 0.4756
# epoch : 15
# training acc 0.9466
# validation acc 0.4756
# Spoof
# Training data set after removing two instances : 2048
# Complete Val data set : 1226
# Complete Test data set : 818
# epoch : 1
# training acc 0.7134
# validation acc 0.4657
# epoch : 2
# training acc 0.7637
# validation acc 0.4780
# epoch : 3
# training acc 0.8018
# validation acc 0.4772
# epoch : 4
# training acc 0.8203
# validation acc 0.4869
# epoch : 5
# training acc 0.8311
# validation acc 0.4984
# epoch : 6
# training acc 0.8413
# validation acc 0.4951
# epoch : 7
# training acc 0.8423
# validation acc 0.4992
# epoch : 8
# training acc 0.8413
# validation acc 0.4976
# epoch : 9
# training acc 0.8545
# validation acc 0.5024
# epoch : 10
# training acc 0.8403
# validation acc 0.5024
# epoch : 11
# training acc 0.8511
# validation acc 0.5024
# epoch : 12
# training acc 0.8564
# validation acc 0.5000
# epoch : 13
# training acc 0.8608
# validation acc 0.5024
# epoch : 14
# training acc 0.8584
# validation acc 0.5008
# epoch : 15
# training acc 0.8643
# validation acc 0.5016

# %%
model = models.resnet18(pretrained=True)
# print(model.eval())

# move the input and model to GPU for speed if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")




import math 


for i in os.listdir('D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_HSV_test'):
    print(i)
    link_train = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\Train_HSV\\'+i+''
    link_test = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_HSV_test\\'+i+''
    model_address = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\model_whi_vs_nat\\{}.pth'.format(i,i)

    
    text_file = i

    transform    = transforms.Compose([
                                        
                                    transforms.Resize((224,224)),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                    std=[0.229, 0.224, 0.225])
                                ])

    training_dataset = datasets.ImageFolder(link_train ,transform = transform)
    testing_dataset = datasets.ImageFolder(link_test,transform = transform)

    training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=48, shuffle=True)
    # testing data 

    val_dataset, test_dataset = random_split(testing_dataset,[math.floor(len(testing_dataset)*0.6), math.ceil(len(testing_dataset)*0.4)])

    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = 32, shuffle=False)
    testing_loader = torch.utils.data.DataLoader(test_dataset, batch_size = 32, shuffle=False)


    print("Training data set after removing two instances : {}".format(len(training_dataset)))
    print("Complete Val data set : {}".format(len(val_dataset)))
    print("Complete Test data set : {}".format(len(test_dataset)))
    classes = ('Live', 'Spoof')

    for param in model.parameters():
        param.requires_grad = False

    import torch.nn as nn

    n_inputs = model.fc.in_features
    last_layer = nn.Linear(n_inputs, len(classes))
    model.fc=nn.Linear(n_inputs,2)
    # model.to(device)
   # print(model.eval())
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)


    model.load_state_dict(torch.load(model_address))

    def get_all_preds(model,loader):
        all_preds = torch.tensor([])
        #   all_preds.to(device)
        for batch in loader:
            images,labels = batch
            #   images = images.to(device)
            #   labels = labels.to(device)
        

            preds = model(images)
            all_preds = torch.cat((all_preds , preds),dim=0)
        return all_preds


    with torch.no_grad():
        prediction_loader = torch.utils.data.DataLoader(test_dataset,batch_size = 32)
        test_pred = get_all_preds(model,prediction_loader)
        
    print(test_pred.shape)
    test_labels = [label for _, label in test_dataset]
    # print(test_labels)

    test_set = torch.FloatTensor(test_labels)


    def get_num_correct(preds,labels):
        return preds.argmax(dim=1).eq(labels).sum().item()

    pred_correct = get_num_correct(test_pred,test_set)
    # print('total correct:',pred_correct)
    # test accuracy


    stacked = torch.stack((test_set,test_pred.argmax(dim=1)),dim=1)



    t11=[]
    p11=[]
    for p in stacked:
        t1,p1=p.tolist()
        t11.append(t1)
        p11.append(p1)
        
        

    from sklearn.metrics import confusion_matrix
    # print('Confusion Matrix',confusion_matrix(t11,p11))


    m = nn.Softmax(dim=1)
    # input = torch.randn(2, 3)
    # output = m(input)
    test_prediction = m(test_pred)
    
    

    far, tpr, threshold = roc_curve(test_set ,
                                        test_prediction [:,1],
                                        drop_intermediate = True )
    
     #calculate AUC of model
    auc = roc_auc_score(test_set ,test_prediction [:,1])
    print('area under curce:',auc)
 
    #print(far, tpr,threshold)
    plt.figure(figsize=(6,4))
   
    plt.plot(far, tpr, linewidth=2)

    plt.plot([0,1], [0,1], 'k--' )

    plt.rcParams['font.size'] = 12
    plt.fill_between(far, tpr, facecolor='lightgreen', alpha=0.7)
    plt.text(0.95, 0.05, 'AUC = %0.4f' % auc, ha='right', fontsize=12, weight='bold', color='blue')
    plt.title(' ROC curve -  White v/s Natural Background - HSV')

    plt.xlabel('False Positive Rate (1 - Specificity)')

    plt.ylabel('True Positive Rate (Sensitivity)')

    plt.show()
   

    def compute_eer(fpr,tpr,threshold):
        """ Returns equal error rate (EER) and the corresponding threshold. """
        fnr = 1-tpr
        abs_diffs = np.abs(fpr - fnr)
        min_index = np.argmin(abs_diffs)
        eer = np.mean((fpr[min_index], fnr[min_index]))
        return eer*100

    print('compute_eer',compute_eer(far,tpr,threshold))
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import precision_score
    from sklearn.metrics import recall_score
    from sklearn.metrics import f1_score
    Accuracies = accuracy_score(t11,p11)
    Precision = precision_score(t11,p11)
    Recall = recall_score(t11,p11)
    F1Score = f1_score(t11,p11)

    with open("D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\"+text_file+".txt", "a") as f:
        print('accuracy:',pred_correct/len(test_dataset),file=f)
        print('Accuracy:',Accuracies,file=f)
        print('Precision',Precision,file=f)
        print('Recall',Recall,file=f)
        print('F1Score',F1Score,file=f)
        print('Confusion Matrix',confusion_matrix(t11,p11),file=f)
        print('compute_eer',compute_eer(far,tpr,threshold),file=f)
        print('area under the curve',auc,file=f)
# Out:
# Live
# Training data set after removing two instances : 768
# Complete Val data set : 614
# Complete Test data set : 410
# torch.Size([410, 2])
# area under curce: 0.7564123937221654
# compute_eer 29.738741098859222
# Spoof
# Training data set after removing two instances : 2048
# Complete Val data set : 1226
# Complete Test data set : 818
# torch.Size([818, 2])
# area under curce: 0.5707538992210526
# compute_eer 44.98885082826689

# %% [markdown]
# ## Natural(train) v/s White(test) - HSV Color space

# %%
for i in os.listdir('D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_HSV_train'):
    print(i)
    link_train = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_HSV_train\\'+i+''
    link_test = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\Test_HSV\\'+i+''
    model_address = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\model_nat_vs_whi\\{}.pth'.format(i,i)

    transform    = transforms.Compose([
                                        
                                        transforms.Resize((224,224)),
                                        transforms.ToTensor(),
                                        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                    std=[0.229, 0.224, 0.225])
                                ])

    training_dataset = datasets.ImageFolder(link_train ,transform = transform)
    testing_dataset = datasets.ImageFolder(link_test,transform = transform)

    training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=48, shuffle=True)
    # testing data 

    val_dataset, test_dataset = random_split(testing_dataset,[math.floor(len(testing_dataset)*0.6), math.ceil(len(testing_dataset)*0.4)])

    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = 32, shuffle=False)
    testing_loader = torch.utils.data.DataLoader(test_dataset, batch_size = 32, shuffle=False)

    print("Training data set after removing two instances : {}".format(len(training_dataset)))
    print("Complete Val data set : {}".format(len(val_dataset)))
    print("Complete Test data set : {}".format(len(test_dataset)))
    classes = ('Live', 'Spoof')

    for param in model.parameters():
        param.requires_grad = False

    import torch.nn as nn

    n_inputs = model.fc.in_features
    last_layer = nn.Linear(n_inputs, len(classes))
    model.fc=nn.Linear(n_inputs,2)
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)


    splits = KFold(n_splits= 3, shuffle = True, random_state = 42)

    epochs = 15
    running_loss_history = []
    running_corrects_history = []
    val_running_loss_history = []
    val_running_corrects_history = []

    for e in range(epochs):
        running_loss = 0.0
        running_corrects = 0.0
        val_running_loss = 0.0
        val_running_corrects = 0.0
        for inputs, labels in training_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            _, preds = torch.max(outputs, 1)
            running_loss += loss.item()
            running_corrects += torch.sum(preds == labels.data)
        else:
            with torch.no_grad():
                for val_inputs, val_labels in val_loader:
                    val_inputs = val_inputs.to(device)
                    val_labels = val_labels.to(device)
                    val_outputs = model(val_inputs)
                    val_loss = criterion(val_outputs, val_labels)

                    _, val_preds = torch.max(val_outputs, 1)
                    val_running_loss += val_loss.item()
                    val_running_corrects += torch.sum(val_preds == val_labels.data)
        
            epoch_loss = running_loss/len(training_loader.dataset)
            epoch_acc = running_corrects.float()/ len(training_loader.dataset)
            running_loss_history.append(epoch_loss)
            running_corrects_history.append(epoch_acc)

            val_epoch_loss = val_running_loss/len(val_loader.dataset)
            val_epoch_acc = val_running_corrects.float()/ len(val_loader.dataset)
            val_running_loss_history.append(val_epoch_loss)
            val_running_corrects_history.append(val_epoch_acc)
            print('epoch :', (e+1))
            print('training acc {:.4f} '.format(epoch_acc.item()))
            print('validation acc {:.4f} '.format( val_epoch_acc.item()))

    torch.save(model.state_dict(),model_address)
# Out:
# Live
# Training data set after removing two instances : 768
# Complete Val data set : 614
# Complete Test data set : 410
# epoch : 1
# training acc 0.6784
# validation acc 0.6173
# epoch : 2
# training acc 0.8372
# validation acc 0.6303
# epoch : 3
# training acc 0.8841
# validation acc 0.6857
# epoch : 4
# training acc 0.9089
# validation acc 0.6792
# epoch : 5
# training acc 0.9089
# validation acc 0.7101
# epoch : 6
# training acc 0.9323
# validation acc 0.6906
# epoch : 7
# training acc 0.9427
# validation acc 0.6873
# epoch : 8
# training acc 0.9271
# validation acc 0.6564
# epoch : 9
# training acc 0.9323
# validation acc 0.6629
# epoch : 10
# training acc 0.9310
# validation acc 0.7231
# epoch : 11
# training acc 0.9466
# validation acc 0.7296
# epoch : 12
# training acc 0.9492
# validation acc 0.6873
# epoch : 13
# training acc 0.9583
# validation acc 0.7264
# epoch : 14
# training acc 0.9557
# validation acc 0.7248
# epoch : 15
# training acc 0.9518
# validation acc 0.7280
# Spoof
# Training data set after removing two instances : 2048
# Complete Val data set : 1228
# Complete Test data set : 820
# epoch : 1
# training acc 0.6489
# validation acc 0.5147
# epoch : 2
# training acc 0.7603
# validation acc 0.5293
# epoch : 3
# training acc 0.8042
# validation acc 0.5480
# epoch : 4
# training acc 0.8145
# validation acc 0.5611
# epoch : 5
# training acc 0.8262
# validation acc 0.5383
# epoch : 6
# training acc 0.8457
# validation acc 0.5505
# epoch : 7
# training acc 0.8413
# validation acc 0.5423
# epoch : 8
# training acc 0.8306
# validation acc 0.5383
# epoch : 9
# training acc 0.8516
# validation acc 0.5537
# epoch : 10
# training acc 0.8501
# validation acc 0.5554
# epoch : 11
# training acc 0.8428
# validation acc 0.5440
# epoch : 12
# training acc 0.8457
# validation acc 0.5537
# epoch : 13
# training acc 0.8291
# validation acc 0.5383
# epoch : 14
# training acc 0.8657
# validation acc 0.5505
# epoch : 15
# training acc 0.8545
# validation acc 0.5407

# %%
model = models.resnet18(pretrained=True)
# print(model.eval())

# move the input and model to GPU for speed if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")




import math 


for i in os.listdir('D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_HSV_test'):
    print(i)
    link_train = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\Train_HSV\\'+i+''
    link_test = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_HSV_test\\'+i+''
    model_address = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\model_nat_vs_whi\\{}.pth'.format(i,i)

    
    text_file = i

    transform    = transforms.Compose([
                                        
                                    transforms.Resize((224,224)),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                    std=[0.229, 0.224, 0.225])
                                ])

    training_dataset = datasets.ImageFolder(link_train ,transform = transform)
    testing_dataset = datasets.ImageFolder(link_test,transform = transform)

    training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=48, shuffle=True)
    # testing data 

    val_dataset, test_dataset = random_split(testing_dataset,[math.floor(len(testing_dataset)*0.6), math.ceil(len(testing_dataset)*0.4)])

    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = 32, shuffle=False)
    testing_loader = torch.utils.data.DataLoader(test_dataset, batch_size = 32, shuffle=False)


    print("Training data set after removing two instances : {}".format(len(training_dataset)))
    print("Complete Val data set : {}".format(len(val_dataset)))
    print("Complete Test data set : {}".format(len(test_dataset)))
    classes = ('Live', 'Spoof')

    for param in model.parameters():
        param.requires_grad = False

    import torch.nn as nn

    n_inputs = model.fc.in_features
    last_layer = nn.Linear(n_inputs, len(classes))
    model.fc=nn.Linear(n_inputs,2)
    # model.to(device)
   # print(model.eval())
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)


    model.load_state_dict(torch.load(model_address))

    def get_all_preds(model,loader):
        all_preds = torch.tensor([])
        #   all_preds.to(device)
        for batch in loader:
            images,labels = batch
            #   images = images.to(device)
            #   labels = labels.to(device)
        

            preds = model(images)
            all_preds = torch.cat((all_preds , preds),dim=0)
        return all_preds


    with torch.no_grad():
        prediction_loader = torch.utils.data.DataLoader(test_dataset,batch_size = 32)
        test_pred = get_all_preds(model,prediction_loader)
        
    print(test_pred.shape)
    test_labels = [label for _, label in test_dataset]
    # print(test_labels)

    test_set = torch.FloatTensor(test_labels)


    def get_num_correct(preds,labels):
        return preds.argmax(dim=1).eq(labels).sum().item()

    pred_correct = get_num_correct(test_pred,test_set)
    # print('total correct:',pred_correct)
    # test accuracy


    stacked = torch.stack((test_set,test_pred.argmax(dim=1)),dim=1)



    t11=[]
    p11=[]
    for p in stacked:
        t1,p1=p.tolist()
        t11.append(t1)
        p11.append(p1)
        
        

    from sklearn.metrics import confusion_matrix
    # print('Confusion Matrix',confusion_matrix(t11,p11))


    m = nn.Softmax(dim=1)
    # input = torch.randn(2, 3)
    # output = m(input)
    test_prediction = m(test_pred)
    
    

    far, tpr, threshold = roc_curve(test_set ,
                                        test_prediction [:,1],
                                        drop_intermediate = True )
    
     #calculate AUC of model
    auc = roc_auc_score(test_set ,test_prediction [:,1])
    print('area under curce:',auc)
 
    #print(far, tpr,threshold)
    plt.figure(figsize=(6,4))
   
    plt.plot(far, tpr, linewidth=2)

    plt.plot([0,1], [0,1], 'k--' )

    plt.rcParams['font.size'] = 12
    plt.fill_between(far, tpr, facecolor='lightgreen', alpha=0.7)
    plt.text(0.95, 0.05, 'AUC = %0.4f' % auc, ha='right', fontsize=12, weight='bold', color='blue')
    plt.title(' ROC curve - Natural v/s White Background - HSV')

    plt.xlabel('False Positive Rate (1 - Specificity)')

    plt.ylabel('True Positive Rate (Sensitivity)')

    plt.show()
   

    def compute_eer(fpr,tpr,threshold):
        """ Returns equal error rate (EER) and the corresponding threshold. """
        fnr = 1-tpr
        abs_diffs = np.abs(fpr - fnr)
        min_index = np.argmin(abs_diffs)
        eer = np.mean((fpr[min_index], fnr[min_index]))
        return eer*100

    print('compute_eer',compute_eer(far,tpr,threshold))
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import precision_score
    from sklearn.metrics import recall_score
    from sklearn.metrics import f1_score
    Accuracies = accuracy_score(t11,p11)
    Precision = precision_score(t11,p11)
    Recall = recall_score(t11,p11)
    F1Score = f1_score(t11,p11)

    with open("D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\"+text_file+".txt", "a") as f:
        print('accuracy:',pred_correct/len(test_dataset),file=f)
        print('Accuracy:',Accuracies,file=f)
        print('Precision',Precision,file=f)
        print('Recall',Recall,file=f)
        print('F1Score',F1Score,file=f)
        print('Confusion Matrix',confusion_matrix(t11,p11),file=f)
        print('compute_eer',compute_eer(far,tpr,threshold),file=f)
        print('area under the curve',auc,file=f)
# Out:
# Live
# Training data set after removing two instances : 768
# Complete Val data set : 614
# Complete Test data set : 410
# torch.Size([410, 2])
# area under curce: 0.9385791516825837
# compute_eer 13.167734406630311
# Spoof
# Training data set after removing two instances : 2048
# Complete Val data set : 1226
# Complete Test data set : 818
# torch.Size([818, 2])
# area under curce: 0.8576706260722976
# compute_eer 21.149144254278728

# %%
model = models.alexnet(pretrained=True)
print(model.eval())
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# ## Natural vs White (Alexnet) HSV

# %%
for i in os.listdir('D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_HSV_train'):
    print(i)
    link_train = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_HSV_train\\'+i+''
    link_test = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\Test_HSV\\'+i+''
    model_address = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\model_nat_vs_whi\\{}.pth'.format(i,i)

    transform    = transforms.Compose([
                                        
                                        transforms.Resize((224,224)),
                                        transforms.ToTensor(),
                                        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                    std=[0.229, 0.224, 0.225])
                                ])

    training_dataset = datasets.ImageFolder(link_train ,transform = transform)
    testing_dataset = datasets.ImageFolder(link_test,transform = transform)

    training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=48, shuffle=True)
    # testing data 

    val_dataset, test_dataset = random_split(testing_dataset,[math.floor(len(testing_dataset)*0.6), math.ceil(len(testing_dataset)*0.4)])

    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = 32, shuffle=False)
    testing_loader = torch.utils.data.DataLoader(test_dataset, batch_size = 32, shuffle=False)

    print("Training data set after removing two instances : {}".format(len(training_dataset)))
    print("Complete Val data set : {}".format(len(val_dataset)))
    print("Complete Test data set : {}".format(len(test_dataset)))
    classes = ('Live', 'Spoof')

    for param in model.parameters():
        param.requires_grad = False

    import torch.nn as nn

    n_inputs = model.classifier[6].in_features
    last_layer = nn.Linear(n_inputs, len(classes))
    model.fc=nn.Linear(n_inputs,2)
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)


    splits = KFold(n_splits= 3, shuffle = True, random_state = 42)

    epochs = 15
    running_loss_history = []
    running_corrects_history = []
    val_running_loss_history = []
    val_running_corrects_history = []

    for e in range(epochs):
        running_loss = 0.0
        running_corrects = 0.0
        val_running_loss = 0.0
        val_running_corrects = 0.0
        for inputs, labels in training_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            #loss.backward()
            optimizer.step()

            _, preds = torch.max(outputs, 1)
            running_loss += loss.item()
            running_corrects += torch.sum(preds == labels.data)
        else:
            with torch.no_grad():
                for val_inputs, val_labels in val_loader:
                    val_inputs = val_inputs.to(device)
                    val_labels = val_labels.to(device)
                    val_outputs = model(val_inputs)
                    val_loss = criterion(val_outputs, val_labels)

                    _, val_preds = torch.max(val_outputs, 1)
                    val_running_loss += val_loss.item()
                    val_running_corrects += torch.sum(val_preds == val_labels.data)
        
            epoch_loss = running_loss/len(training_loader.dataset)
            epoch_acc = running_corrects.float()/ len(training_loader.dataset)
            running_loss_history.append(epoch_loss)
            running_corrects_history.append(epoch_acc)

            val_epoch_loss = val_running_loss/len(val_loader.dataset)
            val_epoch_acc = val_running_corrects.float()/ len(val_loader.dataset)
            val_running_loss_history.append(val_epoch_loss)
            val_running_corrects_history.append(val_epoch_acc)
            print('epoch :', (e+1))
            print('training acc {:.4f} '.format(epoch_acc.item()))
            print('validation acc {:.4f} '.format( val_epoch_acc.item()))

    torch.save(model.state_dict(),model_address)
# Out:
# Live
# Training data set after removing two instances : 768
# Complete Val data set : 614
# Complete Test data set : 410
# epoch : 1
# training acc 0.0000
# validation acc 0.0016
# epoch : 2
# training acc 0.0000
# validation acc 0.0016
# epoch : 3
# training acc 0.0000
# validation acc 0.0016
# epoch : 4
# training acc 0.0000
# validation acc 0.0016
# epoch : 5
# training acc 0.0000
# validation acc 0.0016
# epoch : 6
# training acc 0.0000
# validation acc 0.0016
# epoch : 7
# training acc 0.0000
# validation acc 0.0016
# epoch : 8
# training acc 0.0000
# validation acc 0.0016
# epoch : 9
# training acc 0.0000
# validation acc 0.0016
# epoch : 10
# training acc 0.0000
# validation acc 0.0016
# epoch : 11
# training acc 0.0000
# validation acc 0.0016
# epoch : 12
# training acc 0.0000
# validation acc 0.0016
# epoch : 13
# training acc 0.0000
# validation acc 0.0016
# epoch : 14
# training acc 0.0000
# validation acc 0.0016
# epoch : 15
# training acc 0.0000
# validation acc 0.0016
# Spoof
# Training data set after removing two instances : 2048
# Complete Val data set : 1228
# Complete Test data set : 820
# epoch : 1
# training acc 0.0015
# validation acc 0.0016
# epoch : 2
# training acc 0.0015
# validation acc 0.0016
# epoch : 3
# training acc 0.0015
# validation acc 0.0016
# epoch : 4
# training acc 0.0015
# validation acc 0.0016
# epoch : 5
# training acc 0.0015
# validation acc 0.0016
# epoch : 6
# training acc 0.0015
# validation acc 0.0016
# epoch : 7
# training acc 0.0015
# validation acc 0.0016
# epoch : 8
# training acc 0.0015
# validation acc 0.0016
# epoch : 9
# training acc 0.0015
# validation acc 0.0016
# epoch : 10
# training acc 0.0015
# validation acc 0.0016
# epoch : 11
# training acc 0.0015
# validation acc 0.0016
# epoch : 12
# training acc 0.0015
# validation acc 0.0016
# epoch : 13
# training acc 0.0015
# validation acc 0.0016
# epoch : 14
# training acc 0.0015
# validation acc 0.0016
# epoch : 15
# training acc 0.0015
# validation acc 0.0016

# %%
model = models.alexnet(pretrained=True)
# print(model.eval())

# move the input and model to GPU for speed if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")




import math 


for i in os.listdir('D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_HSV_test'):
    print(i)
    link_train = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\Train_HSV\\'+i+''
    link_test = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_HSV_test\\'+i+''
    model_address = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\model_nat_vs_whi\\{}.pth'.format(i,i)

    
    text_file = i

    transform    = transforms.Compose([
                                        
                                    transforms.Resize((224,224)),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                    std=[0.229, 0.224, 0.225])
                                ])

    training_dataset = datasets.ImageFolder(link_train ,transform = transform)
    testing_dataset = datasets.ImageFolder(link_test,transform = transform)

    training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=48, shuffle=True)
    # testing data 

    val_dataset, test_dataset = random_split(testing_dataset,[math.floor(len(testing_dataset)*0.6), math.ceil(len(testing_dataset)*0.4)])

    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = 32, shuffle=False)
    testing_loader = torch.utils.data.DataLoader(test_dataset, batch_size = 32, shuffle=False)


    print("Training data set after removing two instances : {}".format(len(training_dataset)))
    print("Complete Val data set : {}".format(len(val_dataset)))
    print("Complete Test data set : {}".format(len(test_dataset)))
    classes = ('Live', 'Spoof')

    for param in model.parameters():
        param.requires_grad = False

    import torch.nn as nn

    n_inputs = model.classifier[6].in_features
    last_layer = nn.Linear(n_inputs, len(classes))
    model.fc=nn.Linear(n_inputs,2)
    # model.to(device)
   # print(model.eval())
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)


    model.load_state_dict(torch.load(model_address))

    def get_all_preds(model,loader):
        all_preds = torch.tensor([])
        #   all_preds.to(device)
        for batch in loader:
            images,labels = batch
            #   images = images.to(device)
            #   labels = labels.to(device)
        

            preds = model(images)
            all_preds = torch.cat((all_preds , preds),dim=0)
        return all_preds


    with torch.no_grad():
        prediction_loader = torch.utils.data.DataLoader(test_dataset,batch_size = 32)
        test_pred = get_all_preds(model,prediction_loader)
        
    print(test_pred.shape)
    test_labels = [label for _, label in test_dataset]
    # print(test_labels)

    test_set = torch.FloatTensor(test_labels)


    def get_num_correct(preds,labels):
        return preds.argmax(dim=1).eq(labels).sum().item()

    pred_correct = get_num_correct(test_pred,test_set)
    # print('total correct:',pred_correct)
    # test accuracy


    stacked = torch.stack((test_set,test_pred.argmax(dim=1)),dim=1)



    t11=[]
    p11=[]
    for p in stacked:
        t1,p1=p.tolist()
        t11.append(t1)
        p11.append(p1)
        
        

    from sklearn.metrics import confusion_matrix
    # print('Confusion Matrix',confusion_matrix(t11,p11))


    m = nn.Softmax(dim=1)
    # input = torch.randn(2, 3)
    # output = m(input)
    test_prediction = m(test_pred)
    
    

    far, tpr, threshold = roc_curve(test_set ,
                                        test_prediction [:,1],
                                        drop_intermediate = True )
    
     #calculate AUC of model
    auc = roc_auc_score(test_set ,test_prediction [:,1])
    print('area under curce:',auc)
 
    #print(far, tpr,threshold)
    plt.figure(figsize=(6,4))
   
    plt.plot(far, tpr, linewidth=2)

    plt.plot([0,1], [0,1], 'k--' )

    plt.rcParams['font.size'] = 12
    plt.fill_between(far, tpr, facecolor='lightgreen', alpha=0.7)
    plt.text(0.95, 0.05, 'AUC = %0.4f' % auc, ha='right', fontsize=12, weight='bold', color='blue')
    plt.title(' ROC curve - Natural v/s White Background - HSV - Alexnet')

    plt.xlabel('False Positive Rate (1 - Specificity)')

    plt.ylabel('True Positive Rate (Sensitivity)')

    plt.show()
   

    def compute_eer(fpr,tpr,threshold):
        """ Returns equal error rate (EER) and the corresponding threshold. """
        fnr = 1-tpr
        abs_diffs = np.abs(fpr - fnr)
        min_index = np.argmin(abs_diffs)
        eer = np.mean((fpr[min_index], fnr[min_index]))
        return eer*100

    print('compute_eer',compute_eer(far,tpr,threshold))
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import precision_score
    from sklearn.metrics import recall_score
    from sklearn.metrics import f1_score
    Accuracies = accuracy_score(t11,p11)
    Precision = precision_score(t11,p11,average='micro')
    Recall = recall_score(t11,p11,average='micro')
    F1Score = f1_score(t11,p11,average='micro')

    with open("D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\"+text_file+".txt", "a") as f:
        print('accuracy:',pred_correct/len(test_dataset),file=f)
        print('Accuracy:',Accuracies,file=f)
        print('Precision',Precision,file=f)
        print('Recall',Recall,file=f)
        print('F1Score',F1Score,file=f)
        print('Confusion Matrix',confusion_matrix(t11,p11),file=f)
        print('compute_eer',compute_eer(far,tpr,threshold),file=f)
        print('area under the curve',auc,file=f)
# Out:
# Live
# Training data set after removing two instances : 768
# Complete Val data set : 614
# Complete Test data set : 410
# torch.Size([410, 1000])
# area under curce: 0.7014825920373148
# compute_eer 34.63268365817092
# Spoof
# Training data set after removing two instances : 2048
# Complete Val data set : 1226
# Complete Test data set : 818
# torch.Size([818, 1000])
# area under curce: 0.5127349491977491
# compute_eer 48.165557329697336

# %% [markdown]
# ## White vs Natural -HSV-Alexnet

# %%
## model = models.alexnet(pretrained=True)
# print(model.eval())

# move the input and model to GPU for speed if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")




import math 


for i in os.listdir('D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_HSV_test'):
    print(i)
    link_train = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\Train_HSV\\'+i+''
    link_test = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_HSV_test\\'+i+''
    model_address = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\model_nat_vs_whi\\{}.pth'.format(i,i)

    
    text_file = i

    transform    = transforms.Compose([
                                        
                                    transforms.Resize((224,224)),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                    std=[0.229, 0.224, 0.225])
                                ])

    training_dataset = datasets.ImageFolder(link_train ,transform = transform)
    testing_dataset = datasets.ImageFolder(link_test,transform = transform)

    training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=48, shuffle=True)
    # testing data 

    val_dataset, test_dataset = random_split(testing_dataset,[math.floor(len(testing_dataset)*0.6), math.ceil(len(testing_dataset)*0.4)])

    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = 32, shuffle=False)
    testing_loader = torch.utils.data.DataLoader(test_dataset, batch_size = 32, shuffle=False)


    print("Training data set after removing two instances : {}".format(len(training_dataset)))
    print("Complete Val data set : {}".format(len(val_dataset)))
    print("Complete Test data set : {}".format(len(test_dataset)))
    classes = ('Live', 'Spoof')

    for param in model.parameters():
        param.requires_grad = False

    import torch.nn as nn

    n_inputs = model.classifier[6].in_features
    last_layer = nn.Linear(n_inputs, len(classes))
    model.fc=nn.Linear(n_inputs,2)
    # model.to(device)
   # print(model.eval())
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)


    model.load_state_dict(torch.load(model_address))

    def get_all_preds(model,loader):
        all_preds = torch.tensor([])
        #   all_preds.to(device)
        for batch in loader:
            images,labels = batch
            #   images = images.to(device)
            #   labels = labels.to(device)
        

            preds = model(images)
            all_preds = torch.cat((all_preds , preds),dim=0)
        return all_preds


    with torch.no_grad():
        prediction_loader = torch.utils.data.DataLoader(test_dataset,batch_size = 32)
        test_pred = get_all_preds(model,prediction_loader)
        
    print(test_pred.shape)
    test_labels = [label for _, label in test_dataset]
    # print(test_labels)

    test_set = torch.FloatTensor(test_labels)


    def get_num_correct(preds,labels):
        return preds.argmax(dim=1).eq(labels).sum().item()

    pred_correct = get_num_correct(test_pred,test_set)
    # print('total correct:',pred_correct)
    # test accuracy


    stacked = torch.stack((test_set,test_pred.argmax(dim=1)),dim=1)



    t11=[]
    p11=[]
    for p in stacked:
        t1,p1=p.tolist()
        t11.append(t1)
        p11.append(p1)
        
        

    from sklearn.metrics import confusion_matrix
    # print('Confusion Matrix',confusion_matrix(t11,p11))


    m = nn.Softmax(dim=1)
    # input = torch.randn(2, 3)
    # output = m(input)
    test_prediction = m(test_pred)
    
    

    far, tpr, threshold = roc_curve(test_set ,
                                        test_prediction [:,1],
                                        drop_intermediate = True )
    
     #calculate AUC of model
    auc = roc_auc_score(test_set ,test_prediction [:,1])
    print('area under curce:',auc)
 
    #print(far, tpr,threshold)
    plt.figure(figsize=(6,4))
   
    plt.plot(far, tpr, linewidth=2)

    plt.plot([0,1], [0,1], 'k--' )

    plt.rcParams['font.size'] = 12
    plt.fill_between(far, tpr, facecolor='lightgreen', alpha=0.7)
    plt.text(0.95, 0.05, 'AUC = %0.4f' % auc, ha='right', fontsize=12, weight='bold', color='blue')
    plt.title(' ROC curve - White v/s Natural Background - HSV - Alexnet')

    plt.xlabel('False Positive Rate (1 - Specificity)')

    plt.ylabel('True Positive Rate (Sensitivity)')

    plt.show()
   

    def compute_eer(fpr,tpr,threshold):
        """ Returns equal error rate (EER) and the corresponding threshold. """
        fnr = 1-tpr
        abs_diffs = np.abs(fpr - fnr)
        min_index = np.argmin(abs_diffs)
        eer = np.mean((fpr[min_index], fnr[min_index]))
        return eer*100

    print('compute_eer',compute_eer(far,tpr,threshold))
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import precision_score
    from sklearn.metrics import recall_score
    from sklearn.metrics import f1_score
    Accuracies = accuracy_score(t11,p11)
    Precision = precision_score(t11,p11,average='micro')
    Recall = recall_score(t11,p11,average='micro')
    F1Score = f1_score(t11,p11,average='micro')

    with open("D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\"+text_file+".txt", "a") as f:
        print('accuracy:',pred_correct/len(test_dataset),file=f)
        print('Accuracy:',Accuracies,file=f)
        print('Precision',Precision,file=f)
        print('Recall',Recall,file=f)
        print('F1Score',F1Score,file=f)
        print('Confusion Matrix',confusion_matrix(t11,p11),file=f)
        print('compute_eer',compute_eer(far,tpr,threshold),file=f)
        print('area under the curve',auc,file=f)
# Out:
# Live
# Training data set after removing two instances : 768
# Complete Val data set : 614
# Complete Test data set : 410
# torch.Size([410, 1000])
# area under curce: 0.6938513175748053
# compute_eer 34.149825037491965
# Spoof
# Training data set after removing two instances : 2048
# Complete Val data set : 1226
# Complete Test data set : 818
# torch.Size([818, 1000])
# area under curce: 0.5018350546325401
# compute_eer 49.51504265828469

# %%
# from resnet import *
import matplotlib.pyplot as plt
import torch.nn as nn 
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset, DataLoader, random_split, SubsetRandomSampler, WeightedRandomSampler
import torch.nn.functional as F 
from sklearn.model_selection import KFold
import os
import io
import cv2
from PIL import *
import PIL.ImageOps
import requests
from PIL import Image
import numpy as np
#import matplotlib
#matplotlib.use('agg')
#import matplotlib.pyplot as plt
import torch
import torch.nn as nn 
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset, DataLoader, random_split, SubsetRandomSampler, WeightedRandomSampler
import torch.nn.functional as F 
from torch.optim import lr_scheduler
import time
import copy
from sklearn.model_selection import KFold
import os
import io
import cv2
from PIL import *
import PIL.ImageOps
from PIL import Image
from sklearn.metrics import roc_curve, auc,roc_auc_score

model = models.resnet18(pretrained=True)
# print(model.eval())

# move the input and model to GPU for speed if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")




import math 


for i in os.listdir('D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_test'):
    print(i)
    link_train = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\Train\\'+i+''
    link_test = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_2_patch\\natural_test\\'+i+''
    model_address = 'D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\model\\{}.pth'.format(i,i)
    
    
    text_file = i

    transform    = transforms.Compose([
                                        
                                    transforms.Resize((224,224)),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                    std=[0.229, 0.224, 0.225])
                                ])

    training_dataset = datasets.ImageFolder(link_train ,transform = transform)
    testing_dataset = datasets.ImageFolder(link_test,transform = transform)

    training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=48, shuffle=True)
    # testing data 

    val_dataset, test_dataset = random_split(testing_dataset,[math.floor(len(testing_dataset)*0.6), math.ceil(len(testing_dataset)*0.4)])

    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = 32, shuffle=False)
    testing_loader = torch.utils.data.DataLoader(test_dataset, batch_size = 32, shuffle=False)


    print("Training data set after removing two instances : {}".format(len(training_dataset)))
    print("Complete Val data set : {}".format(len(val_dataset)))
    print("Complete Test data set : {}".format(len(test_dataset)))
    classes = ('Live', 'Spoof')

    for param in model.parameters():
        param.requires_grad = False

    import torch.nn as nn

    n_inputs = model.fc.in_features
    last_layer = nn.Linear(n_inputs, len(classes))
    model.fc=nn.Linear(n_inputs,2)
    # model.to(device)
   # print(model.eval())
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)


    model.load_state_dict(torch.load(model_address))

    def get_all_preds(model,loader):
        all_preds = torch.tensor([])
        #   all_preds.to(device)
        for batch in loader:
            images,labels = batch
            #   images = images.to(device)
            #   labels = labels.to(device)
        

            preds = model(images)
            all_preds = torch.cat((all_preds , preds),dim=0)
        return all_preds


    with torch.no_grad():
        prediction_loader = torch.utils.data.DataLoader(test_dataset,batch_size = 32)
        test_pred = get_all_preds(model,prediction_loader)
        
    print(test_pred.shape)
    test_labels = [label for _, label in test_dataset]
    # print(test_labels)

    test_set = torch.FloatTensor(test_labels)


    def get_num_correct(preds,labels):
        return preds.argmax(dim=1).eq(labels).sum().item()

    pred_correct = get_num_correct(test_pred,test_set)
    # print('total correct:',pred_correct)
    # test accuracy


    stacked = torch.stack((test_set,test_pred.argmax(dim=1)),dim=1)



    t11=[]
    p11=[]
    for p in stacked:
        t1,p1=p.tolist()
        t11.append(t1)
        p11.append(p1)
        
        

    from sklearn.metrics import confusion_matrix
    # print('Confusion Matrix',confusion_matrix(t11,p11))


    m = nn.Softmax(dim=1)
    # input = torch.randn(2, 3)
    # output = m(input)
    test_prediction = m(test_pred)
    
    

    far, tpr, threshold = roc_curve(test_set ,
                                        test_prediction [:,1],
                                        drop_intermediate = True )
    
     #calculate AUC of model
    auc = roc_auc_score(test_set ,test_prediction [:,1])
    print('area under curce:',auc)
 
    #print(far, tpr,threshold)
    plt.figure(figsize=(6,4))
   
    plt.plot(far, tpr, linewidth=2)

    plt.plot([0,1], [0,1], 'k--' )

    plt.rcParams['font.size'] = 12
    plt.fill_between(far, tpr, facecolor='lightgreen', alpha=0.7)
    plt.text(0.95, 0.05, 'AUC = %0.4f' % auc, ha='right', fontsize=12, weight='bold', color='blue')
    plt.title(' ROC curve - Baseline (Natural v/s White Background)')

    plt.xlabel('False Positive Rate (1 - Specificity)')

    plt.ylabel('True Positive Rate (Sensitivity)')

    plt.show()
   

    def compute_eer(fpr,tpr,threshold):
        """ Returns equal error rate (EER) and the corresponding threshold. """
        fnr = 1-tpr
        abs_diffs = np.abs(fpr - fnr)
        min_index = np.argmin(abs_diffs)
        eer = np.mean((fpr[min_index], fnr[min_index]))
        return eer*100

    print('compute_eer',compute_eer(far,tpr,threshold))
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import precision_score
    from sklearn.metrics import recall_score
    from sklearn.metrics import f1_score
    Accuracies = accuracy_score(t11,p11)
    Precision = precision_score(t11,p11)
    Recall = recall_score(t11,p11)
    F1Score = f1_score(t11,p11)

    with open("D:\\Fall 2021\\Applied ML - AIT 736\\final new\\Experiment_1_patch\\"+text_file+".txt", "a") as f:
        print('accuracy:',pred_correct/len(test_dataset),file=f)
        print('Accuracy:',Accuracies,file=f)
        print('Precision',Precision,file=f)
        print('Recall',Recall,file=f)
        print('F1Score',F1Score,file=f)
        print('Confusion Matrix',confusion_matrix(t11,p11),file=f)
        print('compute_eer',compute_eer(far,tpr,threshold),file=f)
        print('area under the curve',auc,file=f)
# Out:
# Live
# Training data set after removing two instances : 768
# Complete Val data set : 614
# Complete Test data set : 410
# torch.Size([410, 2])
# area under curce: 0.6250922860749244
# compute_eer 40.74519517016362
# Spoof
# Training data set after removing two instances : 2048
# Complete Val data set : 1228
# Complete Test data set : 820
# torch.Size([820, 2])
# area under curce: 0.6776382762130981
# compute_eer 37.56183808690372
